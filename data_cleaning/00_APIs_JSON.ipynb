# %%
# L1V1 - Simple APIs

# %%
import requests
import json
import pandas as pd

# %%
# Define the URL
url = "https://api.fda.gov/food/enforcement.json"

# Send a GET request
response = requests.get(url)

# Check the status code
print(response.status_code)
# Out:
# 200

# %%
# Extract the data 

data = response.json()
data
# Out:
# {'meta': {'disclaimer': 'Do not rely on openFDA to make decisions regarding medical care. While we make every effort to ensure that data is accurate, you should assume all results are unvalidated. We may limit or otherwise restrict your access to the API in line with our Terms of Service.',
#   'terms': 'https://open.fda.gov/terms/',
#   'license': 'https://open.fda.gov/license/',
#   'last_updated': '2025-02-19',
#   'results': {'skip': 0, 'limit': 1, 'total': 27064}},
#  'results': [{'status': 'Terminated',
#    'city': 'Davie',
#    'state': 'FL',
#    'country': 'United States',
#    'classification': 'Class II',
#    'openfda': {},
#    'product_type': 'Food',
#    'event_id': '75272',
#    'recalling_firm': 'Pharmatech LLC',
#    'address_1': '4131 SW 47th Ave Ste 1403',
#    'address_2': '',
#    'postal_code': '33314-4036',
#    'voluntary_mandated': 'Voluntary: Firm initiated',
#    'initial_firm_notification': 'Letter',
#    'distribution_pattern': 'FL, MI, MS, and OH.',
#    'recall_number': 'F-0276-2017',
#    'product_description': 'CytoDetox, Hydrolyzed Clinoptilolite Fragments, 1 oz./30 mL, OTC Non-Sterile.  Dietary supplement.',
#    'product_quantity': '1,990 bottles',
#    'reason_for_recall': 'Recall initiated as a precautionary measure due to potential risk of product contamination with Burkholderia cepacia.',
#    'recall_initiation_date': '20160808',
#    'center_classification_date': '20161025',
#    'termination_date': '20240923',
#    'report_date': '20161102',
#    'code_info': 'UPC No. 632687615989; Lot No. 30661601, Exp. Date 05/2018.',
#    'more_code_info': ''}]}

# %%
# L1V2 - JSON

# %%
data.keys()
# Out:
# dict_keys(['meta', 'results'])

# %%
data['meta']
# Out:
# {'disclaimer': 'Do not rely on openFDA to make decisions regarding medical care. While we make every effort to ensure that data is accurate, you should assume all results are unvalidated. We may limit or otherwise restrict your access to the API in line with our Terms of Service.',
#  'terms': 'https://open.fda.gov/terms/',
#  'license': 'https://open.fda.gov/license/',
#  'last_updated': '2025-02-19',
#  'results': {'skip': 0, 'limit': 1, 'total': 27064}}

# %%
data['results']
# Out:
# [{'status': 'Terminated',
#   'city': 'Davie',
#   'state': 'FL',
#   'country': 'United States',
#   'classification': 'Class II',
#   'openfda': {},
#   'product_type': 'Food',
#   'event_id': '75272',
#   'recalling_firm': 'Pharmatech LLC',
#   'address_1': '4131 SW 47th Ave Ste 1403',
#   'address_2': '',
#   'postal_code': '33314-4036',
#   'voluntary_mandated': 'Voluntary: Firm initiated',
#   'initial_firm_notification': 'Letter',
#   'distribution_pattern': 'FL, MI, MS, and OH.',
#   'recall_number': 'F-0276-2017',
#   'product_description': 'CytoDetox, Hydrolyzed Clinoptilolite Fragments, 1 oz./30 mL, OTC Non-Sterile.  Dietary supplement.',
#   'product_quantity': '1,990 bottles',
#   'reason_for_recall': 'Recall initiated as a precautionary measure due to potential risk of product contamination with Burkholderia cepacia.',
#   'recall_initiation_date': '20160808',
#   'center_classification_date': '20161025',
#   'termination_date': '20240923',
#   'report_date': '20161102',
#   'code_info': 'UPC No. 632687615989; Lot No. 30661601, Exp. Date 05/2018.',
#   'more_code_info': ''}]

# %%
type(data['results'])
# Out:
# list

# %%
len(data['results'])
# Out:
# 1

# %%
data['results'][0]
# Out:
# {'status': 'Terminated',
#  'city': 'Davie',
#  'state': 'FL',
#  'country': 'United States',
#  'classification': 'Class II',
#  'openfda': {},
#  'product_type': 'Food',
#  'event_id': '75272',
#  'recalling_firm': 'Pharmatech LLC',
#  'address_1': '4131 SW 47th Ave Ste 1403',
#  'address_2': '',
#  'postal_code': '33314-4036',
#  'voluntary_mandated': 'Voluntary: Firm initiated',
#  'initial_firm_notification': 'Letter',
#  'distribution_pattern': 'FL, MI, MS, and OH.',
#  'recall_number': 'F-0276-2017',
#  'product_description': 'CytoDetox, Hydrolyzed Clinoptilolite Fragments, 1 oz./30 mL, OTC Non-Sterile.  Dietary supplement.',
#  'product_quantity': '1,990 bottles',
#  'reason_for_recall': 'Recall initiated as a precautionary measure due to potential risk of product contamination with Burkholderia cepacia.',
#  'recall_initiation_date': '20160808',
#  'center_classification_date': '20161025',
#  'termination_date': '20240923',
#  'report_date': '20161102',
#  'code_info': 'UPC No. 632687615989; Lot No. 30661601, Exp. Date 05/2018.',
#  'more_code_info': ''}

# %%
# L1V3 - Parameters

# %%
# Define the URL
url = "https://api.fda.gov/food/enforcement.json?search=state:HI&limit=5"

# Send a GET request
response = requests.get(url)

# Check the status code
print(response.status_code)
# Out:
# 200

# %%
# Extract the data 

data = response.json()
data
# Out:
# {'meta': {'disclaimer': 'Do not rely on openFDA to make decisions regarding medical care. While we make every effort to ensure that data is accurate, you should assume all results are unvalidated. We may limit or otherwise restrict your access to the API in line with our Terms of Service.',
#   'terms': 'https://open.fda.gov/terms/',
#   'license': 'https://open.fda.gov/license/',
#   'last_updated': '2025-02-19',
#   'results': {'skip': 0, 'limit': 5, 'total': 64}},
#  'results': [{'country': 'United States',
#    'city': 'Kapaa',
#    'address_1': '5915 Olohena Rd',
#    'reason_for_recall': 'Candy was made using carob powder that is currently under recall by the direct supplier due to potential Salmonella contamination.',
#    'address_2': 'Unit H',
#    'product_quantity': 'All',
#    'code_info': 'UPC for single truffles: 11386711886    No lot codes or expiry dates',
#    'center_classification_date': '20140825',
#    'distribution_pattern': 'HI only',
#    'state': 'HI',
#    'product_description': 'Tiny Isle Chocolate Truffles Macadamia Nut: Gluten Free, Raw, Vegan; individual 1 oz. candies,    Tiny Isle  5915 Olohena Road, Unit H  Kapaa, HI 96746',
#    'report_date': '20140903',
#    'classification': 'Class I',
#    'openfda': {},
#    'recalling_firm': 'Florimont, Inc.',
#    'recall_number': 'F-2387-2014',
#    'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#    'product_type': 'Food',
#    'event_id': '68994',
#    'termination_date': '20141104',
#    'recall_initiation_date': '20140725',
#    'postal_code': '96746-7709',
#    'voluntary_mandated': 'Voluntary: Firm initiated',
#    'status': 'Terminated'},
#   {'status': 'Terminated',
#    'city': 'Honolulu',
#    'state': 'HI',
#    'country': 'United States',
#    'classification': 'Class II',
#    'openfda': {},
#    'product_type': 'Food',
#    'event_id': '82877',
#    'recalling_firm': 'Regal Food Inc./dba The Pizza Shop',
#    'address_1': '3040 Ualena St',
#    'address_2': 'N/A',
#    'postal_code': '96819-1984',
#    'voluntary_mandated': 'Voluntary: Firm initiated',
#    'initial_firm_notification': 'Letter',
#    'distribution_pattern': 'HI only - island of Oahu',
#    'recall_number': 'F-1459-2019',
#    'product_description': "Regal's Fundraising Cookies: Cornflake flavor.  Net Weight 12 oz. (340 grams).    All varieties have the same ingredient list:  Flour, Sugar, Cotton Seed Oil, Butter Blend, Chocolate Chips, Salted Butter, Vanilla Extract, Salt, Baking Soda.    Regal Foods,  Honolulu, HI  www.regalfoodsusa.com",
#    'product_quantity': 'N/A',
#    'reason_for_recall': 'FDA inspection found that allergen sub ingredients are not declared on the label - wheat, soy, milk.',
#    'recall_initiation_date': '20190515',
#    'center_classification_date': '20190614',
#    'termination_date': '20191119',
#    'report_date': '20190626',
#    'code_info': 'all manufacturing codes - i.e.05/02/19'},
#   {'country': 'United States',
#    'city': 'Kapaa',
#    'address_1': '5915 Olohena Rd',
#    'reason_for_recall': 'Candy was made using carob powder that is currently under recall by the direct supplier due to potential Salmonella contamination.',
#    'address_2': 'Unit H',
#    'product_quantity': 'All',
#    'code_info': 'UPC for single truffles: 11386711886    No lot codes or expiry dates',
#    'center_classification_date': '20140825',
#    'distribution_pattern': 'HI only',
#    'state': 'HI',
#    'product_description': 'Tiny Isle Chocolate Truffles Spicy Lava: Gluten Free, Raw, Vegan; individual 1 oz. candies,    Tiny Isle  5915 Olohena Road, Unit H  Kapaa, HI 96746',
#    'report_date': '20140903',
#    'classification': 'Class I',
#    'openfda': {},
#    'recalling_firm': 'Florimont, Inc.',
#    'recall_number': 'F-2386-2014',
#    'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#    'product_type': 'Food',
#    'event_id': '68994',
#    'termination_date': '20141104',
#    'recall_initiation_date': '20140725',
#    'postal_code': '96746-7709',
#    'voluntary_mandated': 'Voluntary: Firm initiated',
#    'status': 'Terminated'},
#   {'country': 'United States',
#    'city': 'Kapaa',
#    'address_1': '5915 Olohena Rd',
#    'reason_for_recall': 'Candy was made using carob powder that is currently under recall by the direct supplier due to potential Salmonella contamination.',
#    'address_2': 'Unit H',
#    'product_quantity': 'ALL',
#    'code_info': 'UPC 011386071157No lot codes or expiry dates',
#    'center_classification_date': '20140825',
#    'distribution_pattern': 'HI only',
#    'state': 'HI',
#    'product_description': 'Tiny Isle Original Fudge, 2 oz.; Organic-Raw- Gluten Free;  Ingredients: Cacao powder, coconut oil. agave nectar, carob powder, vanilla, sea salt.  Keep cold.    Tiny Isle  5915 Olohena Road, Unit H  Kapaa, HI 96746',
#    'report_date': '20140903',
#    'classification': 'Class I',
#    'openfda': {},
#    'recalling_firm': 'Florimont, Inc.',
#    'recall_number': 'F-2380-2014',
#    'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#    'product_type': 'Food',
#    'event_id': '68994',
#    'termination_date': '20141104',
#    'recall_initiation_date': '20140725',
#    'postal_code': '96746-7709',
#    'voluntary_mandated': 'Voluntary: Firm initiated',
#    'status': 'Terminated'},
#   {'status': 'Terminated',
#    'city': 'Honolulu',
#    'state': 'HI',
#    'country': 'United States',
#    'classification': 'Class III',
#    'openfda': {},
#    'product_type': 'Food',
#    'event_id': '68673',
#    'recalling_firm': 'Modern Macaroni Co Ltd',
#    'address_1': '1708 Mary St',
#    'address_2': '',
#    'postal_code': '96819-3103',
#    'voluntary_mandated': 'Voluntary: Firm initiated',
#    'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#    'distribution_pattern': 'HI and one location in San Francisco',
#    'recall_number': 'F-2089-2014',
#    'product_description': 'Hula Brand Products; Hana Ebi Red; artificially colored shrimp flakes);  Packed in 1 lb. (545 g) and 6 oz. packages.  Servins size 2 pinches (1 g)    Manufactured by Modern Macaroni Co., Honolulu, HI  Serving size is "2" pinches',
#    'product_quantity': 'unknown',
#    'reason_for_recall': 'FDA sample 466576 found 208.46 ppm of Sulfites in Hana Ebi dried shrimp product.',
#    'recall_initiation_date': '20140620',
#    'center_classification_date': '20140709',
#    'termination_date': '20150226',
#    'report_date': '20140716',
#    'code_info': 'Red - 1 lb UPC 73366-22044;  Red - 0.6 oz. UPD 73366-22042;  Green - i lb. - UPC 73366-22045;  Green - 0.6 oz. UPC 73366-22043.  No other code numbers',
#    'more_code_info': ''}]}

# %%
# Define the URL
url = "https://api.fda.gov/food/enforcement.json"

# Define the parameters
parameters = {"limit":5, "skip":20}

# Send a GET request
response = requests.get(url, params=parameters)

# Check the status code
print(response.status_code)

# Extract the data 
data = response.json()
data
# Out:
# 200
# {'meta': {'disclaimer': 'Do not rely on openFDA to make decisions regarding medical care. While we make every effort to ensure that data is accurate, you should assume all results are unvalidated. We may limit or otherwise restrict your access to the API in line with our Terms of Service.',
#   'terms': 'https://open.fda.gov/terms/',
#   'license': 'https://open.fda.gov/license/',
#   'last_updated': '2025-02-19',
#   'results': {'skip': 20, 'limit': 5, 'total': 27064}},
#  'results': [{'status': 'Terminated',
#    'city': 'Ventura',
#    'state': 'CA',
#    'country': 'United States',
#    'classification': 'Class I',
#    'openfda': {},
#    'product_type': 'Food',
#    'event_id': '76035',
#    'recalling_firm': 'Altijira Murray Products, LLC',
#    'address_1': '675 E Santa Clara St Unit 2087',
#    'address_2': 'N/A',
#    'postal_code': '93002-7115',
#    'voluntary_mandated': 'Voluntary: Firm initiated',
#    'initial_firm_notification': 'Press Release',
#    'distribution_pattern': 'U.S. distribution to the following; CA, NY.    No foreign distribution.',
#    'recall_number': 'F-1540-2017',
#    'product_description': "foxy's california pistachio  1 Pint",
#    'product_quantity': '400 cases (total)',
#    'reason_for_recall': 'Potential Listeria monocytogenes contamination.',
#    'recall_initiation_date': '20161220',
#    'center_classification_date': '20170224',
#    'termination_date': '20170330',
#    'report_date': '20170308',
#    'code_info': 'Best By: March 17th 2017, March 18th 2017, March 19th 2017, March 20th 2017',
#    'more_code_info': ''},
#   {'country': 'United States',
#    'city': 'Sebastopol',
#    'address_1': '9141 Green Valley Rd',
#    'reason_for_recall': 'Manzana Products Co. is initiating a recall of three varieties of apple sauce after receiving customer complaints or finding small pieces of glass in the product.',
#    'address_2': '',
#    'product_quantity': '70,157 jars',
#    'code_info': 'ALL CODES  Through AUG 08, 2018',
#    'center_classification_date': '20170320',
#    'distribution_pattern': 'Nationwide.',
#    'state': 'CA',
#    'product_description': "Trader Joe's First Crush Unsweetened Gravenstein Apple Sauce;   24 oz. glass jar.  Best Before date stamped on top of lid.    UPC:00015905     Distributed by Trader Joe's, Monrovia, CA",
#    'report_date': '20170329',
#    'classification': 'Class II',
#    'openfda': {},
#    'recalling_firm': 'Manzana Products Co.,  Inc.',
#    'recall_number': 'F-1643-2017',
#    'initial_firm_notification': 'Telephone',
#    'product_type': 'Food',
#    'event_id': '76589',
#    'termination_date': '20190529',
#    'more_code_info': '',
#    'recall_initiation_date': '20170224',
#    'postal_code': '95472-2245',
#    'voluntary_mandated': 'Voluntary: Firm initiated',
#    'status': 'Terminated'},
#   {'status': 'Terminated',
#    'city': 'City Of Industry',
#    'state': 'CA',
#    'country': 'United States',
#    'classification': 'Class II',
#    'openfda': {},
#    'product_type': 'Food',
#    'event_id': '70344',
#    'recalling_firm': 'Health One Pharmaceuticals Inc',
#    'address_1': '13260 Temple Ave',
#    'address_2': 'N/A',
#    'postal_code': '91746-1511',
#    'voluntary_mandated': 'Voluntary: Firm initiated',
#    'initial_firm_notification': 'Letter',
#    'distribution_pattern': 'Nationwide in US: CA, TN, WA, ID,     and worldwide:  Hong Kong, Vietnam, China, Singapore',
#    'recall_number': 'F-1681-2015',
#    'product_description': 'EST -700 Calcium',
#    'product_quantity': '1035 units',
#    'reason_for_recall': 'Health One Pharmaceuticals is recalling dietary supplements due to significant violations of the cGMP regulations for dietary supplements.',
#    'recall_initiation_date': '20150204',
#    'center_classification_date': '20150330',
#    'termination_date': '20150331',
#    'report_date': '20150408',
#    'code_info': '8520'},
#   {'status': 'Terminated',
#    'city': 'Coloma',
#    'state': 'MI',
#    'country': 'United States',
#    'classification': 'Class II',
#    'openfda': {},
#    'product_type': 'Food',
#    'event_id': '71948',
#    'recalling_firm': 'Coloma Frozen Foods, Inc.',
#    'address_1': '4145 Coloma Rd',
#    'address_2': 'N/A',
#    'postal_code': '49038-8967',
#    'voluntary_mandated': 'Voluntary: Firm initiated',
#    'initial_firm_notification': 'Letter',
#    'distribution_pattern': 'Domestic: MI, IN, IL, WI, MO, NE, OH    Foreign: Canada  DOD/VA: None',
#    'recall_number': 'F-3091-2015',
#    'product_description': 'Red Tart Pitted Cherries, Straight Packed (No Sugar),  5 lbs. bulk pails, 30 lbs, in bulk pails',
#    'product_quantity': '146,220 lbs. Total',
#    'reason_for_recall': 'Potential for adulteration - elevated mold, yeast, and coliform counts',
#    'recall_initiation_date': '20150807',
#    'center_classification_date': '20150909',
#    'termination_date': '20160428',
#    'report_date': '20150916',
#    'code_info': 'Lot Codes: 15190  15191  15196  15198  15200  15201  15202  15203  15204  15205  15212  15215  43145  43146  43147  43148  43149  43150  43151  43152  43153  43155  43156  43157  43158  43159  43160  43161  43162  43163  43164  43165  43166  43167  43168  43169  43170  43171  43172  43173  43174  43175  43176  43177  43178  43179  43180  43181  43182  43183  43184  43583  43584  43585  43586  43587  43588  43589  43590  43591  43592  43593  43594  43595  43596  43597  43598  43599  43600  43601  43602  43603'},
#   {'country': 'United States',
#    'city': 'Colonial Heights',
#    'address_1': '15900 Sabra Way',
#    'reason_for_recall': 'Michigan Dept. of Agriculture collected a sample of Sabra Hummus that came up positive for L. Monocytogenes.  Baltimore District is  working with VDACS to investigate.',
#    'address_2': '',
#    'product_quantity': '9312 Cases',
#    'code_info': 'UPC/SKU    040822017497 / 301290',
#    'center_classification_date': '20150428',
#    'distribution_pattern': 'The product was distributed nationwide.',
#    'state': 'VA',
#    'product_description': 'Sabra Classic Hummus, 17oz Six Pack UPC 040822017497 / 301290  Sabra Dipping Co. LLC, White Plains, NY',
#    'report_date': '20150506',
#    'classification': 'Class I',
#    'openfda': {},
#    'recalling_firm': 'Sabra Dipping Company, LLC',
#    'recall_number': 'F-2085-2015',
#    'initial_firm_notification': 'Two or more of the following: Email, Fax, Letter, Press Release, Telephone, Visit',
#    'product_type': 'Food',
#    'event_id': '70934',
#    'termination_date': '20150826',
#    'more_code_info': '',
#    'recall_initiation_date': '20150407',
#    'postal_code': '23834-5935',
#    'voluntary_mandated': 'Voluntary: Firm initiated',
#    'status': 'Terminated'}]}

# %%
# L1V4 - From JSON to DataFrame

# %%
# Define the URL
url = "https://api.fda.gov/food/enforcement.json?limit=1000"

# Send a GET request
response = requests.get(url)

# Check the status code
print(response.status_code)
# Out:
# 200

# %%
# Extract the data 

data = response.json()

# check if the data is correct
print(type(data))
print(data.keys())
# Out:
# <class 'dict'>
# dict_keys(['meta', 'results'])

# %%
type(data['results'][0])
# Out:
# dict

# %%
first_result = data['results'][0]

# %%
first_result.keys() # columns of the DF
# Out:
# dict_keys(['status', 'city', 'state', 'country', 'classification', 'openfda', 'product_type', 'event_id', 'recalling_firm', 'address_1', 'address_2', 'postal_code', 'voluntary_mandated', 'initial_firm_notification', 'distribution_pattern', 'recall_number', 'product_description', 'product_quantity', 'reason_for_recall', 'recall_initiation_date', 'center_classification_date', 'termination_date', 'report_date', 'code_info', 'more_code_info'])

# %%
first_result.values() # check the "rows""
# Out:
# dict_values(['Terminated', 'Davie', 'FL', 'United States', 'Class II', {}, 'Food', '75272', 'Pharmatech LLC', '4131 SW 47th Ave Ste 1403', '', '33314-4036', 'Voluntary: Firm initiated', 'Letter', 'FL, MI, MS, and OH.', 'F-0276-2017', 'CytoDetox, Hydrolyzed Clinoptilolite Fragments, 1 oz./30 mL, OTC Non-Sterile.  Dietary supplement.', '1,990 bottles', 'Recall initiated as a precautionary measure due to potential risk of product contamination with Burkholderia cepacia.', '20160808', '20161025', '20240923', '20161102', 'UPC No. 632687615989; Lot No. 30661601, Exp. Date 05/2018.', ''])

# %%
df = pd.DataFrame([first_result])
df
# Out:
#        status   city state        country classification openfda product_type  \
# 0  Terminated  Davie    FL  United States       Class II      {}         Food
#
#   event_id  recalling_firm                  address_1  ... recall_number  \
# 0    75272  Pharmatech LLC  4131 SW 47th Ave Ste 1403  ...   F-0276-2017
#
#                                  product_description product_quantity  \
# 0  CytoDetox, Hydrolyzed Clinoptilolite Fragments...    1,990 bottles
#
#                                    reason_for_recall recall_initiation_date  \
# 0  Recall initiated as a precautionary measure du...               20160808
#
#   center_classification_date termination_date report_date  \
# 0                   20161025         20240923    20161102
#
#                                            code_info more_code_info
# 0  UPC No. 632687615989; Lot No. 30661601, Exp. D...
#
# [1 rows x 25 columns]

# %%
df.dtypes #check the types
# Out:
# status                        object
# city                          object
# state                         object
# country                       object
# classification                object
# openfda                       object
# product_type                  object
# event_id                      object
# recalling_firm                object
# address_1                     object
# address_2                     object
# postal_code                   object
# voluntary_mandated            object
# initial_firm_notification     object
# distribution_pattern          object
# recall_number                 object
# product_description           object
# product_quantity              object
# reason_for_recall             object
# recall_initiation_date        object
# center_classification_date    object
# termination_date              object
# report_date                   object
# code_info                     object
# more_code_info                object
# dtype: object

# %%
# Convert the dates

df['recall_initiation_date'] = pd.to_datetime(df['recall_initiation_date'])
df['center_classification_date'] = pd.to_datetime(df['center_classification_date'])
df['termination_date'] = pd.to_datetime(df['termination_date'])
df['report_date'] = pd.to_datetime(df['report_date'])
df
# Out:
#        status   city state        country classification openfda product_type  \
# 0  Terminated  Davie    FL  United States       Class II      {}         Food
#
#   event_id  recalling_firm                  address_1  ... recall_number  \
# 0    75272  Pharmatech LLC  4131 SW 47th Ave Ste 1403  ...   F-0276-2017
#
#                                  product_description product_quantity  \
# 0  CytoDetox, Hydrolyzed Clinoptilolite Fragments...    1,990 bottles
#
#                                    reason_for_recall recall_initiation_date  \
# 0  Recall initiated as a precautionary measure du...             2016-08-08
#
#   center_classification_date termination_date report_date  \
# 0                 2016-10-25       2024-09-23  2016-11-02
#
#                                            code_info more_code_info
# 0  UPC No. 632687615989; Lot No. 30661601, Exp. D...
#
# [1 rows x 25 columns]

# %%
# Converting the product quantity

df['product_quantity'] = df['product_quantity'].str.split().str[0].replace(',', '', regex=True).astype(int)
df
# Out:
#        status   city state        country classification openfda product_type  \
# 0  Terminated  Davie    FL  United States       Class II      {}         Food
#
#   event_id  recalling_firm                  address_1  ... recall_number  \
# 0    75272  Pharmatech LLC  4131 SW 47th Ave Ste 1403  ...   F-0276-2017
#
#                                  product_description product_quantity  \
# 0  CytoDetox, Hydrolyzed Clinoptilolite Fragments...             1990
#
#                                    reason_for_recall recall_initiation_date  \
# 0  Recall initiated as a precautionary measure du...             2016-08-08
#
#   center_classification_date termination_date  report_date  \
# 0                 2016-10-25       2024-09-23   2016-11-02
#
#                                            code_info more_code_info
# 0  UPC No. 632687615989; Lot No. 30661601, Exp. D...
#
# [1 rows x 25 columns]

# %%
df.dtypes # check types now
# Out:
# status                                object
# city                                  object
# state                                 object
# country                               object
# classification                        object
# openfda                               object
# product_type                          object
# event_id                              object
# recalling_firm                        object
# address_1                             object
# address_2                             object
# postal_code                           object
# voluntary_mandated                    object
# initial_firm_notification             object
# distribution_pattern                  object
# recall_number                         object
# product_description                   object
# product_quantity                       int64
# reason_for_recall                     object
# recall_initiation_date        datetime64[ns]
# center_classification_date    datetime64[ns]
# termination_date              datetime64[ns]
# report_date                   datetime64[ns]
# code_info                             object
# more_code_info                        object
# dtype: object

# %%
# L1V5 - Pagination

# %%
# Getting all the results

url = "https://api.fda.gov/food/enforcement.json"

dataframes = [] #we will save the results in a list of dfs

# Iterating over the range to fetch 25,000 records in batches of 1,000
for i in range(25):
    params = {
        "limit": 1000, #number of requests you will make per time, this depends on the API
        "skip": i * 1000, #you will repeat the process for the next batch
    }
    # Fetching data from the API
    response = requests.get(url, params=params).json() # Creating a DataFrame from the results
    df = pd.DataFrame(response['results'])
    dataframes.append(df)

# %%
# Concatenating all DataFrames into a single DataFrame
final_df = pd.concat(dataframes, ignore_index=True)
final_df
# Out:
#            status              city state        country classification  \
# 0      Terminated             Davie    FL  United States       Class II
# 1      Terminated          Millbrae    CA  United States       Class II
# 2      Terminated             Miami    FL  United States        Class I
# 3      Terminated     Pompano Beach    FL  United States        Class I
# 4      Terminated  Rancho Dominguez    CA  United States      Class III
# ...           ...               ...   ...            ...            ...
# 24995  Terminated  Saint Petersburg    FL  United States        Class I
# 24996  Terminated            Coloma    MI  United States       Class II
# 24997  Terminated              Troy    MI  United States       Class II
# 24998  Terminated           Chicago    IL  United States       Class II
# 24999  Terminated             Miami    FL  United States       Class II
#
#       openfda product_type event_id                recalling_firm  \
# 0          {}         Food    75272                Pharmatech LLC
# 1          {}         Food    75069     Magic Gourmet Trading Inc
# 2          {}         Food    69516             Oasis Brands, Inc
# 3          {}         Food    62750      FreshPoint South Florida
# 4          {}         Food    85253       Organic By Nature, Inc.
# ...       ...          ...      ...                           ...
# 24995      {}         Food    81156     Working Cow Homemade Inc.
# 24996      {}         Food    71948     Coloma Frozen Foods, Inc.
# 24997      {}         Food    68422              Good Herbs, Inc.
# 24998      {}         Food    88262        5000 Years Foods, Inc.
# 24999      {}         Food    74054  Sunset Natural Products Inc.
#
#                        address_1  ... recall_number  \
# 0      4131 SW 47th Ave Ste 1403  ...   F-0276-2017
# 1                  375 Adrian Rd  ...   F-0865-2017
# 2               13439 NW 19 LANE  ...   F-0609-2015
# 3                2300 NW 19th St  ...   F-1922-2012
# 4              2610 Homestead Pl  ...   F-0904-2020
# ...                          ...  ...           ...
# 24995      4711 34th St N Unit F  ...   F-0564-2019
# 24996             4145 Coloma Rd  ...   F-3090-2015
# 24997              550 Oliver Dr  ...   F-0341-2015
# 24998         3465 N Kimball Ave  ...   F-0857-2021
# 24999            7345 SW 45th St  ...   F-0992-2017
#
#                                      product_description  \
# 0      CytoDetox, Hydrolyzed Clinoptilolite Fragments...
# 1      Koi Palace Mini Moon Cake: Single Box - Mini O...
# 2      Crema GuateLinda (Guatemalan Style Cream) in i...
# 3      Yellow Onion.  Product is labeled in part:  "*...
# 4      Pure Planet Organic Parasite Cleanse;  Net Wt....
# ...                                                  ...
# 24995    JY Chocolate Peanut Butter Ice Cream, 3 gallons
# 24996  Red Tart Pitted Cherries, 5 Parts Fruit and 1 ...
# 24997  Good Herbs, Inc., MALE HORMONE SUPPORT, 1 oz b...
# 24998  5000 Years Foods BABY NAPA KIMCHI in 128 oz, 6...
# 24999                               Ramto, bulk capsules
#
#                                       product_quantity  \
# 0                                        1,990 bottles
# 1                           2 cases (1 pc/bx, 48bx/cs)
# 2                                           144 pieces
# 3                                              7 cases
# 4                                                   xx
# ...                                                ...
# 24995                                         107 tubs
# 24996                               146,220 lbs. Total
# 24997  Approximately 1204 total units for all products
# 24998                   approximately 54,000 lbs total
# 24999                                        9,290,000
#
#                                        reason_for_recall  \
# 0      Recall initiated as a precautionary measure du...
# 1      Mooncake products, manufactured and distribute...
# 2      Virginia State (VDACS) found Listeria monocyto...
# 3      FreshPoint South Florida is recalling sliced f...
# 4      Firm was notified by supplier that Organic Gro...
# ...                                                  ...
# 24995  Products may be contaminated with  Listeria mo...
# 24996  Potential for adulteration - elevated mold, ye...
# 24997              Products not manufactured under GMP's
# 24998  potential to be contaminated with Listeria mon...
# 24999  Pursuant to a consent decree that prohibits th...
#
#       recall_initiation_date center_classification_date termination_date  \
# 0                   20160808                   20161025         20240923
# 1                   20160831                   20170106         20170111
# 2                   20141010                   20141202         20170328
# 3                   20120727                   20120808         20141008
# 4                   20200224                   20200413         20210202
# ...                      ...                        ...              ...
# 24995               20180928                   20181113         20190426
# 24996               20150807                   20150909         20160428
# 24997               20140505                   20141030         20160203
# 24998               20210706                   20210810         20220201
# 24999               20151013                   20161228         20170410
#
#       report_date                                          code_info  \
# 0        20161102  UPC No. 632687615989; Lot No. 30661601, Exp. D...
# 1        20170118                  FG-M1MOT-UW  Best by Nov 1, 2016.
# 2        20141210  UPC 635349 000390  Best By dates: 07/01/14 thr...
# 3        20120815                                   Item #   302940.
# 4        20200401                                   Lot codes: 72746
# ...           ...                                                ...
# 24995    20181121                           "8/29/2017 - 10/11/2018"
# 24996    20150916  Lot Codes: 15190  15191  15196  15198  15200  ...
# 24997    20141105  All Lots distributed on or after October 17, 2013
# 24998    20210818                          09052021 through 09252021
# 24999    20170104  As persuant to the Consent Decree, the firm ag...
#
#       more_code_info
# 0
# 1
# 2                NaN
# 3
# 4
# ...              ...
# 24995
# 24996            NaN
# 24997
# 24998            NaN
# 24999            NaN
#
# [25000 rows x 25 columns]

# %%
# L1V6 - Analyzing the combined dataframe

# %%
# Convert the dates

# there are two values that are not properly formated
final_df['recall_initiation_date'][20383]
# Out:
# '20121207'

# %%
final_df['recall_initiation_date'][20498]
# Out:
# '02121207'

# %%
# Convert the dates

final_df.at[20383, 'recall_initiation_date'] = '20121207'
final_df.at[20498, 'recall_initiation_date'] = '20121207'

final_df['recall_initiation_date'] = pd.to_datetime(final_df['recall_initiation_date'])
final_df['center_classification_date'] = pd.to_datetime(final_df['center_classification_date'])
final_df['termination_date'] = pd.to_datetime(final_df['termination_date'])
final_df['report_date'] = pd.to_datetime(final_df['report_date'])
final_df
# Out:
#            status              city state        country classification  \
# 0      Terminated             Davie    FL  United States       Class II
# 1      Terminated          Millbrae    CA  United States       Class II
# 2      Terminated             Miami    FL  United States        Class I
# 3      Terminated     Pompano Beach    FL  United States        Class I
# 4      Terminated  Rancho Dominguez    CA  United States      Class III
# ...           ...               ...   ...            ...            ...
# 24995  Terminated  Saint Petersburg    FL  United States        Class I
# 24996  Terminated            Coloma    MI  United States       Class II
# 24997  Terminated              Troy    MI  United States       Class II
# 24998  Terminated           Chicago    IL  United States       Class II
# 24999  Terminated             Miami    FL  United States       Class II
#
#       openfda product_type event_id                recalling_firm  \
# 0          {}         Food    75272                Pharmatech LLC
# 1          {}         Food    75069     Magic Gourmet Trading Inc
# 2          {}         Food    69516             Oasis Brands, Inc
# 3          {}         Food    62750      FreshPoint South Florida
# 4          {}         Food    85253       Organic By Nature, Inc.
# ...       ...          ...      ...                           ...
# 24995      {}         Food    81156     Working Cow Homemade Inc.
# 24996      {}         Food    71948     Coloma Frozen Foods, Inc.
# 24997      {}         Food    68422              Good Herbs, Inc.
# 24998      {}         Food    88262        5000 Years Foods, Inc.
# 24999      {}         Food    74054  Sunset Natural Products Inc.
#
#                        address_1  ... recall_number  \
# 0      4131 SW 47th Ave Ste 1403  ...   F-0276-2017
# 1                  375 Adrian Rd  ...   F-0865-2017
# 2               13439 NW 19 LANE  ...   F-0609-2015
# 3                2300 NW 19th St  ...   F-1922-2012
# 4              2610 Homestead Pl  ...   F-0904-2020
# ...                          ...  ...           ...
# 24995      4711 34th St N Unit F  ...   F-0564-2019
# 24996             4145 Coloma Rd  ...   F-3090-2015
# 24997              550 Oliver Dr  ...   F-0341-2015
# 24998         3465 N Kimball Ave  ...   F-0857-2021
# 24999            7345 SW 45th St  ...   F-0992-2017
#
#                                      product_description  \
# 0      CytoDetox, Hydrolyzed Clinoptilolite Fragments...
# 1      Koi Palace Mini Moon Cake: Single Box - Mini O...
# 2      Crema GuateLinda (Guatemalan Style Cream) in i...
# 3      Yellow Onion.  Product is labeled in part:  "*...
# 4      Pure Planet Organic Parasite Cleanse;  Net Wt....
# ...                                                  ...
# 24995    JY Chocolate Peanut Butter Ice Cream, 3 gallons
# 24996  Red Tart Pitted Cherries, 5 Parts Fruit and 1 ...
# 24997  Good Herbs, Inc., MALE HORMONE SUPPORT, 1 oz b...
# 24998  5000 Years Foods BABY NAPA KIMCHI in 128 oz, 6...
# 24999                               Ramto, bulk capsules
#
#                                       product_quantity  \
# 0                                        1,990 bottles
# 1                           2 cases (1 pc/bx, 48bx/cs)
# 2                                           144 pieces
# 3                                              7 cases
# 4                                                   xx
# ...                                                ...
# 24995                                         107 tubs
# 24996                               146,220 lbs. Total
# 24997  Approximately 1204 total units for all products
# 24998                   approximately 54,000 lbs total
# 24999                                        9,290,000
#
#                                        reason_for_recall  \
# 0      Recall initiated as a precautionary measure du...
# 1      Mooncake products, manufactured and distribute...
# 2      Virginia State (VDACS) found Listeria monocyto...
# 3      FreshPoint South Florida is recalling sliced f...
# 4      Firm was notified by supplier that Organic Gro...
# ...                                                  ...
# 24995  Products may be contaminated with  Listeria mo...
# 24996  Potential for adulteration - elevated mold, ye...
# 24997              Products not manufactured under GMP's
# 24998  potential to be contaminated with Listeria mon...
# 24999  Pursuant to a consent decree that prohibits th...
#
#       recall_initiation_date center_classification_date termination_date  \
# 0                 2016-08-08                 2016-10-25       2024-09-23
# 1                 2016-08-31                 2017-01-06       2017-01-11
# 2                 2014-10-10                 2014-12-02       2017-03-28
# 3                 2012-07-27                 2012-08-08       2014-10-08
# 4                 2020-02-24                 2020-04-13       2021-02-02
# ...                      ...                        ...              ...
# 24995             2018-09-28                 2018-11-13       2019-04-26
# 24996             2015-08-07                 2015-09-09       2016-04-28
# 24997             2014-05-05                 2014-10-30       2016-02-03
# 24998             2021-07-06                 2021-08-10       2022-02-01
# 24999             2015-10-13                 2016-12-28       2017-04-10
#
#       report_date                                          code_info  \
# 0      2016-11-02  UPC No. 632687615989; Lot No. 30661601, Exp. D...
# 1      2017-01-18                  FG-M1MOT-UW  Best by Nov 1, 2016.
# 2      2014-12-10  UPC 635349 000390  Best By dates: 07/01/14 thr...
# 3      2012-08-15                                   Item #   302940.
# 4      2020-04-01                                   Lot codes: 72746
# ...           ...                                                ...
# 24995  2018-11-21                           "8/29/2017 - 10/11/2018"
# 24996  2015-09-16  Lot Codes: 15190  15191  15196  15198  15200  ...
# 24997  2014-11-05  All Lots distributed on or after October 17, 2013
# 24998  2021-08-18                          09052021 through 09252021
# 24999  2017-01-04  As persuant to the Consent Decree, the firm ag...
#
#       more_code_info
# 0
# 1
# 2                NaN
# 3
# 4
# ...              ...
# 24995
# 24996            NaN
# 24997
# 24998            NaN
# 24999            NaN
#
# [25000 rows x 25 columns]

# %%
# Calculate total time taking to resolve a recall
final_df['duration'] = final_df['termination_date'] - final_df['recall_initiation_date']
final_df

# %%
# Sort the dataframe chronologically
sorted_df = final_df.sort_values(by='recall_initiation_date', ascending=True)
sorted_df = sorted_df.dropna(subset=['duration'])
sorted_df

# %%
sorted_df['duration'].mean()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Convert duration from timedelta to integer days
sorted_df['duration_days'] = sorted_df['duration'].dt.days

# Ensure the 'recall_initiation_date' is a datetime type
sorted_df['recall_initiation_date'] = pd.to_datetime(sorted_df['recall_initiation_date'])

# Group by month and calculate average duration
monthly_average = sorted_df.groupby(pd.Grouper(key='recall_initiation_date', freq='M'))['duration_days'].mean()

# Plotting the average duration per month
plt.figure(figsize=(10, 6))  # Set the figure size
plt.plot(monthly_average.index, monthly_average, marker='o', linestyle='-')  # Plot line graph
plt.title('Average Recall Duration Per Month')  # Add a title
plt.xlabel('Month')  # X-axis label
plt.ylabel('Average Duration (days)')  # Y-axis label
plt.grid(True)  # Enable grid for better readability
plt.xticks(rotation=45)  # Rotate date labels for better visibility
plt.tight_layout()  # Adjust layout
plt.show()  # Display the plot
