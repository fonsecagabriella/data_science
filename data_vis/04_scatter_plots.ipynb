# %%
# Environment setup
import pandas as pd
pd.plotting.register_matplotlib_converters()

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

insurance_data = pd.read_csv("../data/insurance_claims.csv")

insurance_data.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
# 2                 134   29         687698       2000-09-06           OH
# 3                 256   41         227811       1990-05-25           IL
# 4                 228   44         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... police_report_available total_claim_amount injury_claim  \
# ...

# %%
plt.figure(figsize=(15, 6))


# to plot 3 figures
sns.scatterplot(y=insurance_data["total_claim_amount"], x=insurance_data["age"], hue=insurance_data["fraud_reported"])

# note, another way to write the above
# sns.scatterplot(data=insurance_data, y="total_claim_amount", x="age", hue="fraud_reported")


plt.xlabel("Age")
plt.ylabel("Total Claim Amount")
plt.title("Months as Customer vs Amount Claimed")




# adds a regression line
# Note: if you use the regline, the hue doesn't work
# sns.regplot(y=insurance_data["total_claim_amount"], x=insurance_data["age"])


plt.show()

# %%
# lmplot ads two regression lines
plt.figure(figsize=(15,6))
sns.lmplot(x="age", y= "total_claim_amount", hue="fraud_reported", data=insurance_data)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# a SWARMPLOT used a categorical variable in the plot
# it helps to see the density of points in each category

sns.swarmplot(x="fraud_reported", y= "total_claim_amount", data=insurance_data)
# Out:
# <Axes: xlabel='fraud_reported', ylabel='total_claim_amount'>
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/categorical.py:3399: UserWarning: 17.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# _NOTE: It’s difficult to say definitively from this image, but there could potentially be two clusters of data points in the ‘N’ category (fraud not reported). One cluster possibly concentrated around lower total claim amounts and another around higher total claim amounts. This could indicate that there might be two different patterns in claim amounts where fraud was not reported._
