# %%
# Environment setup
import pandas as pd
pd.plotting.register_matplotlib_converters()

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

filepath = "../data/iris.csv"
iris = pd.read_csv(filepath, index_col="Id")

iris.head()
# Out:
#     Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  Petal Width (cm)  \
# Id
# 1                 5.1               3.5                1.4               0.2
# 2                 4.9               3.0                1.4               0.2
# 3                 4.7               3.2                1.3               0.2
# 4                 4.6               3.1                1.5               0.2
# 5                 5.0               3.6                1.4               0.2
#
#         Species
# Id
# 1   Iris-setosa
# 2   Iris-setosa
# 3   Iris-setosa
# 4   Iris-setosa
# 5   Iris-setosa

# %%
# we can creta a histogram to see how petal lenght varies in iris flowers

sns.histplot(iris["Petal Length (cm)"])
# Out:
# <Axes: xlabel='Petal Length (cm)', ylabel='Count'>

# %%
# KDE = Kernel Density Estimate 
# it's basically a smooth histogram

sns.kdeplot(data=iris["Petal Length (cm)"], shade=True) # the parameter 'shade' colours the area below the curve
# Out:
# /var/folders/r9/ggpr596s74x4hr8c_sfdzc580000gn/T/ipykernel_902/1716814021.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=iris["Petal Length (cm)"], shade=True) # the parameter 'shade' colours the area below the curve
# <Axes: xlabel='Petal Length (cm)', ylabel='Density'>

# %%
# 2D KDE plots shows the combinations of two different attributes
# the darker part of the figure are more likely to appear (when use kind=kde)

sns.jointplot(data=iris, x="Petal Length (cm)", y="Sepal Width (cm)", kind="kde", shade=True )
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/axisgrid.py:1832: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(x=self.x, y=self.y, **kwargs)

# %%
# histograms for each specieis
sns.histplot(data=iris, x="Petal Length (cm)", hue="Species")

plt.title("Histogram of Petal Lenghts, by Species")
# Out:
# Text(0.5, 1.0, 'Histogram of Petal Lenghts, by Species')

# %%
# Change the style of the figure to the "dark" theme
# themes: darkgrid, whitegrid, dark, white, ticks
sns.set_style("dark")


sns.kdeplot(data=iris, x="Petal Length (cm)", hue="Species", shade="True")
# Out:
# /var/folders/r9/ggpr596s74x4hr8c_sfdzc580000gn/T/ipykernel_902/1482075611.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=iris, x="Petal Length (cm)", hue="Species", shade="True")
# <Axes: xlabel='Petal Length (cm)', ylabel='Density'>
